# %%
print("hello world")
# Out:
# hello world

# %%
# two data types

# %%
#1. series - one dimensional
import pandas as pd
series= pd.Series(["BMW","TOYOTA","HONDA"])

# %%
series
# Out:
# 0       BMW
# 1    TOYOTA
# 2     HONDA
# dtype: object

# %%
Colours= pd.Series(["Red","Blue","white"])
Colours
# Out:
# 0      Red
# 1     Blue
# 2    white
# dtype: object

# %%
#2. Data Frame- 2 dimensional uses key and value same as dictionary most commonly used 
Car_Data=pd.DataFrame({"CAR MAKE":series, "COlOUR":Colours})
Car_Data
# Out:
#   CAR MAKE COlOUR
# 0      BMW    Red
# 1   TOYOTA   Blue
# 2    HONDA  white

# %% [markdown]
# #Import dATA

# %%
Car_Sales= pd.read_csv("7.1 car-sales.csv")

# %%
Car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# #Exporting a DAta frame

# %%
Car_Sales.to_csv("exported-car-sales.csv")

# %%
exported_car_sales= pd.read_csv("exported-car-sales.csv")

# %%
exported_car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ##DESCRIBE DATA

# %%
#attributes
Car_Sales.dtypes

Car_Sales.columns

Car_Sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
#Functions
Car_Sales.describe()

Car_Sales.info()

#Car_Sales.mean()

Car_Sales.sum()

Car_Sales["Price"].sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes
# '$4,000.00$5,000.00$7,000.00$22,000.00$3,500.00$4,500.00$7,500.00$7,000.00$6,250.00$9,700.00'

# %% [markdown]
# #SElecting and Viewing Data in Pandas

# %%
Car_Sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
Car_Sales.head(6)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00

# %%
Car_Sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
#loc function used for specifying index
Car_Sales.loc()

# %%
Car_Sales.loc[4]
# Out:
# Make                Nissan
# Colour               White
# Odometer (KM)       213095
# Doors                    4
# Price            $3,500.00
# Name: 4, dtype: object

# %%
Car_Sales.loc[:5]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00

# %%
#iloc functions is used to specify Position 
Car_Sales.iloc[5]
# Out:
# Make                Toyota
# Colour               Green
# Odometer (KM)        99213
# Doors                    4
# Price            $4,500.00
# Name: 5, dtype: object

# %%
Car_Sales.iloc[:5]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
animals= pd.Series([ "DOG", "CAT","MOUSE"], index=["3","5","6"])

# %%
animals
# Out:
# 3      DOG
# 5      CAT
# 6    MOUSE
# dtype: object

# %%
animals.iloc[:3]
# Out:
# 3      DOG
# 5      CAT
# 6    MOUSE
# dtype: object

# %% [markdown]
# animals.loc[5]  # In dont know why it is not working

# %%
Car_Sales[Car_Sales["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
Car_Sales[Car_Sales.Make=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
Car_Sales[Car_Sales["Odometer (KM)"]>10000]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# #Car_Sales[Car_Sales.Odometer (KM)>10000] # if you have space in the variables then you cannot use . method

# %%
Car_Sales=pd.crosstab(["Price"],["Odometer (KM)"])

# %%
Car_Sales.columns
Car_Sales.columns
# Out:
# Index(['Odometer (KM)'], dtype='object', name='col_0')

# %% [markdown]
# #DATA MAUPULATING

# %%
Car_Sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
Car_Sales["Make"]=Car_Sales["Make"].str.lower()

# %%
Car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  TOYOTA  White         150043      4   $4,000.00
# 1   HONDA    Red          87899      4   $5,000.00
# 2  TOYOTA   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  NISSAN  White         213095      4   $3,500.00
# 5  TOYOTA  Green          99213      4   $4,500.00
# 6   HONDA   Blue          45698      4   $7,500.00
# 7   HONDA   Blue          54738      4   $7,000.00
# 8  TOYOTA  White          60000      4   $6,250.00
# 9  NISSAN  White          31600      4   $9,700.00

# %%
Car_Sales["Make"]=Car_Sales["Make"].str.upper()

# %%
Car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  TOYOTA  White         150043      4   $4,000.00
# 1   HONDA    Red          87899      4   $5,000.00
# 2  TOYOTA   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  NISSAN  White         213095      4   $3,500.00
# 5  TOYOTA  Green          99213      4   $4,500.00
# 6   HONDA   Blue          45698      4   $7,500.00
# 7   HONDA   Blue          54738      4   $7,000.00
# 8  TOYOTA  White          60000      4   $6,250.00
# 9  NISSAN  White          31600      4   $9,700.00

# %%
car_sales_missing= pd.read_csv("9.2 car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)
# Out:
# C:\Users\rebik\AppData\Local\Temp\ipykernel_8580\3620729653.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing= car_sales_missing.dropna()

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %% [markdown]
# # so to get re value you have to import the csv value once more after using Dropna function

# %%
car_sales_missing=pd.read_csv("9.2 car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
#YOU CAN also use inplace= True for same result
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
#export
car_sales_missing.to_csv("car_sales-dropped.csv")

# %%
#creating new column
car_seats= pd.Series([5,5,5,5,5,5,5,5])
Car_Sales["Seats"]=car_seats

# %%
Car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  TOYOTA  White         150043      4   $4,000.00    5.0
# 1   HONDA    Red          87899      4   $5,000.00    5.0
# 2  TOYOTA   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  NISSAN  White         213095      4   $3,500.00    5.0
# 5  TOYOTA  Green          99213      4   $4,500.00    5.0
# 6   HONDA   Blue          45698      4   $7,500.00    5.0
# 7   HONDA   Blue          54738      4   $7,000.00    5.0
# 8  TOYOTA  White          60000      4   $6,250.00    NaN
# 9  NISSAN  White          31600      4   $9,700.00    NaN

# %%
#creating new column using python list so the number of column should be same as the given column
fuel_economy=[1.2,2.3,3.4,4.5,5.4,6.7,8.9,6.998,3.4,10]
Car_Sales["Fuel_Economy"]=fuel_economy

# %%
Car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel_Economy
# 0  TOYOTA  White         150043      4   $4,000.00    5.0         1.200
# 1   HONDA    Red          87899      4   $5,000.00    5.0         2.300
# 2  TOYOTA   Blue          32549      3   $7,000.00    5.0         3.400
# 3     BMW  Black          11179      5  $22,000.00    5.0         4.500
# 4  NISSAN  White         213095      4   $3,500.00    5.0         5.400
# 5  TOYOTA  Green          99213      4   $4,500.00    5.0         6.700
# 6   HONDA   Blue          45698      4   $7,500.00    5.0         8.900
# 7   HONDA   Blue          54738      4   $7,000.00    5.0         6.998
# 8  TOYOTA  White          60000      4   $6,250.00    NaN         3.400
# 9  NISSAN  White          31600      4   $9,700.00    NaN        10.000

# %%
Car_Sales["Fuel Per 100KM"]=Car_Sales["Odometer (KM)"]/100*Car_Sales["Fuel_Economy"]

# %%
Car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel_Economy  \
# 0  TOYOTA  White         150043      4   $4,000.00    5.0         1.200
# 1   HONDA    Red          87899      4   $5,000.00    5.0         2.300
# 2  TOYOTA   Blue          32549      3   $7,000.00    5.0         3.400
# 3     BMW  Black          11179      5  $22,000.00    5.0         4.500
# 4  NISSAN  White         213095      4   $3,500.00    5.0         5.400
# 5  TOYOTA  Green          99213      4   $4,500.00    5.0         6.700
# 6   HONDA   Blue          45698      4   $7,500.00    5.0         8.900
# 7   HONDA   Blue          54738      4   $7,000.00    5.0         6.998
# 8  TOYOTA  White          60000      4   $6,250.00    NaN         3.400
# 9  NISSAN  White          31600      4   $9,700.00    NaN        10.000
#
#    Fuel Per 100KM
# 0      1800.51600
# 1      2021.67700
# 2      1106.66600
# 3       503.05500
# 4     11507.13000
# 5      6647.27100
# 6      4067.12200
# 7      3830.56524
# ...

# %%
#create a column from single value
Car_Sales["Wheels"]=4

# %%
Car_Sales["Passed Road Safety"]=True

# %%
Car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel_Economy  \
# 0  TOYOTA  White         150043      4   $4,000.00    5.0         1.200
# 1   HONDA    Red          87899      4   $5,000.00    5.0         2.300
# 2  TOYOTA   Blue          32549      3   $7,000.00    5.0         3.400
# 3     BMW  Black          11179      5  $22,000.00    5.0         4.500
# 4  NISSAN  White         213095      4   $3,500.00    5.0         5.400
# 5  TOYOTA  Green          99213      4   $4,500.00    5.0         6.700
# 6   HONDA   Blue          45698      4   $7,500.00    5.0         8.900
# 7   HONDA   Blue          54738      4   $7,000.00    5.0         6.998
# 8  TOYOTA  White          60000      4   $6,250.00    NaN         3.400
# 9  NISSAN  White          31600      4   $9,700.00    NaN        10.000
#
#    Fuel Per 100KM  Wheels  Passed Road Safety
# 0      1800.51600       4                True
# 1      2021.67700       4                True
# ...

# %%
Car_Sales.dtypes
# Out:
# Make                   object
# Colour                 object
# Odometer (KM)           int64
# Doors                   int64
# Price                  object
# Seats                 float64
# Fuel_Economy          float64
# Fuel Per 100KM        float64
# Wheels                  int64
# Passed Road Safety       bool
# dtype: object

# %%
#to remove a column
Car_Sales.drop("Wheels",axis=1)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel_Economy  \
# 0  TOYOTA  White         150043      4   $4,000.00    5.0         1.200
# 1   HONDA    Red          87899      4   $5,000.00    5.0         2.300
# 2  TOYOTA   Blue          32549      3   $7,000.00    5.0         3.400
# 3     BMW  Black          11179      5  $22,000.00    5.0         4.500
# 4  NISSAN  White         213095      4   $3,500.00    5.0         5.400
# 5  TOYOTA  Green          99213      4   $4,500.00    5.0         6.700
# 6   HONDA   Blue          45698      4   $7,500.00    5.0         8.900
# 7   HONDA   Blue          54738      4   $7,000.00    5.0         6.998
# 8  TOYOTA  White          60000      4   $6,250.00    NaN         3.400
# 9  NISSAN  White          31600      4   $9,700.00    NaN        10.000
#
#    Fuel Per 100KM  Passed Road Safety
# 0      1800.51600                True
# 1      2021.67700                True
# 2      1106.66600                True
# ...

# %%
Car_Sales.sample()
# Out:
#     Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel_Economy  \
# 6  HONDA   Blue          45698      4  $7,500.00    5.0           8.9
#
#    Fuel Per 100KM  Wheels  Passed Road Safety
# 6        4067.122       4                True

# %%
Car_Sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel_Economy  \
# 7   HONDA   Blue          54738      4   $7,000.00    5.0         6.998
# 0  TOYOTA  White         150043      4   $4,000.00    5.0         1.200
# 1   HONDA    Red          87899      4   $5,000.00    5.0         2.300
# 6   HONDA   Blue          45698      4   $7,500.00    5.0         8.900
# 3     BMW  Black          11179      5  $22,000.00    5.0         4.500
# 2  TOYOTA   Blue          32549      3   $7,000.00    5.0         3.400
# 5  TOYOTA  Green          99213      4   $4,500.00    5.0         6.700
# 4  NISSAN  White         213095      4   $3,500.00    5.0         5.400
# 9  NISSAN  White          31600      4   $9,700.00    NaN        10.000
# 8  TOYOTA  White          60000      4   $6,250.00    NaN         3.400
#
#    Fuel Per 100KM  Wheels  Passed Road Safety
# 7      3830.56524       4                True
# 0      1800.51600       4                True
# ...

# %%
Car_Sales_shuffled=Car_Sales.sample(frac=1)

# %%
Car_Sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel_Economy  \
# 6   HONDA   Blue          45698      4   $7,500.00    5.0         8.900
# 8  TOYOTA  White          60000      4   $6,250.00    NaN         3.400
# 5  TOYOTA  Green          99213      4   $4,500.00    5.0         6.700
# 1   HONDA    Red          87899      4   $5,000.00    5.0         2.300
# 2  TOYOTA   Blue          32549      3   $7,000.00    5.0         3.400
# 3     BMW  Black          11179      5  $22,000.00    5.0         4.500
# 0  TOYOTA  White         150043      4   $4,000.00    5.0         1.200
# 7   HONDA   Blue          54738      4   $7,000.00    5.0         6.998
# 9  NISSAN  White          31600      4   $9,700.00    NaN        10.000
# 4  NISSAN  White         213095      4   $3,500.00    5.0         5.400
#
#    Fuel Per 100KM  Wheels  Passed Road Safety
# 6      4067.12200       4                True
# 8      2040.00000       4                True
# ...

# %%
Car_Sales_shuffled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors       Price  Seats  \
# 0      6   HONDA   Blue          45698      4   $7,500.00    5.0
# 1      8  TOYOTA  White          60000      4   $6,250.00    NaN
# 2      5  TOYOTA  Green          99213      4   $4,500.00    5.0
# 3      1   HONDA    Red          87899      4   $5,000.00    5.0
# 4      2  TOYOTA   Blue          32549      3   $7,000.00    5.0
# 5      3     BMW  Black          11179      5  $22,000.00    5.0
# 6      0  TOYOTA  White         150043      4   $4,000.00    5.0
# 7      7   HONDA   Blue          54738      4   $7,000.00    5.0
# 8      9  NISSAN  White          31600      4   $9,700.00    NaN
# 9      4  NISSAN  White         213095      4   $3,500.00    5.0
#
#    Fuel_Economy  Fuel Per 100KM  Wheels  Passed Road Safety
# 0         8.900      4067.12200       4                True
# 1         3.400      2040.00000       4                True
# 2         6.700      6647.27100       4                True
# ...

# %%
Car_Sales_shuffled.reset_index(drop=True,inplace=True)

# %%
Car_Sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel_Economy  \
# 0   HONDA   Blue          45698      4   $7,500.00    5.0         8.900
# 1  TOYOTA  White          60000      4   $6,250.00    NaN         3.400
# 2  TOYOTA  Green          99213      4   $4,500.00    5.0         6.700
# 3   HONDA    Red          87899      4   $5,000.00    5.0         2.300
# 4  TOYOTA   Blue          32549      3   $7,000.00    5.0         3.400
# 5     BMW  Black          11179      5  $22,000.00    5.0         4.500
# 6  TOYOTA  White         150043      4   $4,000.00    5.0         1.200
# 7   HONDA   Blue          54738      4   $7,000.00    5.0         6.998
# 8  NISSAN  White          31600      4   $9,700.00    NaN        10.000
# 9  NISSAN  White         213095      4   $3,500.00    5.0         5.400
#
#    Fuel Per 100KM  Wheels  Passed Road Safety
# 0      4067.12200       4                True
# 1      2040.00000       4                True
# ...

# %%
Car_Sales_shuffled["Odometer (KM)"]=Car_Sales_shuffled["Odometer (KM)"].apply(lambda x:x/1.6)

# %%
Car_Sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel_Economy  \
# 0   HONDA   Blue      28561.250      4   $7,500.00    5.0         8.900
# 1  TOYOTA  White      37500.000      4   $6,250.00    NaN         3.400
# 2  TOYOTA  Green      62008.125      4   $4,500.00    5.0         6.700
# 3   HONDA    Red      54936.875      4   $5,000.00    5.0         2.300
# 4  TOYOTA   Blue      20343.125      3   $7,000.00    5.0         3.400
# 5     BMW  Black       6986.875      5  $22,000.00    5.0         4.500
# 6  TOYOTA  White      93776.875      4   $4,000.00    5.0         1.200
# 7   HONDA   Blue      34211.250      4   $7,000.00    5.0         6.998
# 8  NISSAN  White      19750.000      4   $9,700.00    NaN        10.000
# 9  NISSAN  White     133184.375      4   $3,500.00    5.0         5.400
#
#    Fuel Per 100KM  Wheels  Passed Road Safety
# 0      4067.12200       4                True
# 1      2040.00000       4                True
# ...

# %%
Car_Sales_shuffled["Odometer (Miles)"]=Car_Sales_shuffled["Odometer (KM)"]

# %%
Car_Sales_shuffled=Car_Sales_shuffled.drop("Odometer (KM)",axis=1)

# %%
Car_Sales_shuffled.replace("Odometer (miles)","Doors")
# Out:
#      Make Colour  Doors       Price  Seats  Fuel_Economy  Fuel Per 100KM  \
# 0   HONDA   Blue      4   $7,500.00    5.0         8.900      4067.12200
# 1  TOYOTA  White      4   $6,250.00    NaN         3.400      2040.00000
# 2  TOYOTA  Green      4   $4,500.00    5.0         6.700      6647.27100
# 3   HONDA    Red      4   $5,000.00    5.0         2.300      2021.67700
# 4  TOYOTA   Blue      3   $7,000.00    5.0         3.400      1106.66600
# 5     BMW  Black      5  $22,000.00    5.0         4.500       503.05500
# 6  TOYOTA  White      4   $4,000.00    5.0         1.200      1800.51600
# 7   HONDA   Blue      4   $7,000.00    5.0         6.998      3830.56524
# 8  NISSAN  White      4   $9,700.00    NaN        10.000      3160.00000
# 9  NISSAN  White      4   $3,500.00    5.0         5.400     11507.13000
#
#    Wheels  Passed Road Safety  Odometer (Miles)
# 0       4                True         28561.250
# 1       4                True         37500.000
# ...
